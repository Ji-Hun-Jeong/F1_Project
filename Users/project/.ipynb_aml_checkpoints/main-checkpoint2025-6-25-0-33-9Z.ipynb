# %%
# %load_ext autoreload
# %autoreload 2
import torch
from Users.project.train_process.train_process import TrainProcess

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
train_process = TrainProcess(device)
train_process.process()
# Out:
# cuda
# Epoch [10/100], Average Loss: 1674916.8750
# Epoch [20/100], Average Loss: 268646.3750
# Epoch [30/100], Average Loss: 22981.6074
# Epoch [40/100], Average Loss: 26623.1836
# Epoch [50/100], Average Loss: 7995.0166
# Epoch [60/100], Average Loss: 3069.9138
# Epoch [70/100], Average Loss: 988.2001
# Epoch [80/100], Average Loss: 877.1415
# Epoch [90/100], Average Loss: 448.5662
# Epoch [100/100], Average Loss: 373.1918
# Epoch [10/100], Average Loss: 86690.9375
# Epoch [20/100], Average Loss: 33730.4961
# Epoch [30/100], Average Loss: 14375.6670
# Epoch [40/100], Average Loss: 6206.5620
# Epoch [50/100], Average Loss: 4526.2939
# Epoch [60/100], Average Loss: 3060.2126
# Epoch [70/100], Average Loss: 1523.0195
# Epoch [80/100], Average Loss: 946.0376
# Epoch [90/100], Average Loss: 495.8151
# Epoch [100/100], Average Loss: 270.2238
# Epoch [10/100], Average Loss: 308991.7812
# Epoch [20/100], Average Loss: 132105.1875
# Epoch [30/100], Average Loss: 48400.8359
# ...
